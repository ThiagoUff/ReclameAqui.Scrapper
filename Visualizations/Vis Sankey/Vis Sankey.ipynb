# %%
import pandas as pd
import numpy as np
import plotly.graph_objects as go

# %%
df = pd.read_excel("../../Dataset/LiveTimRA.xlsx")
df = df.loc[(df['Data'] >= '2022-01-01')]

df['Data_only'] = df['Data'].dt.date

df = df.dropna()
df.columns

# df.to_excel("datasetNA.xlsx")
# Out:
# Index(['Id', 'Titulo', 'Data', 'Localizacao', 'Categoria', 'Problema',
#        'Produto', 'Descricao', 'Status', 'Resolvido', 'Avaliada',
#        'VoltariaNegocio', 'Nota', 'Data_only'],
#       dtype='object')

# %%
categoria = df['Categoria'].unique().tolist()

problema = df['Problema'].unique().tolist()
produto = df['Produto'].unique().tolist()
status = df['Status'].unique().tolist()
# resolvido = df['Resolvido'].unique().tolist()
# notaList = df['Nota'].unique().tolist()

allItens = categoria + problema + produto + status 

origin = []
originLabel = []
dest = []
destLabel = []
value = []
color = []
nodecolor = []


def insertItem (indexOrigin, indexDest, origin, dest, value, color):
    for index in range(len(origin)):
        if(origin[index] == indexOrigin):
               if(dest[index] == indexDest):
                    value[index]+= 1
                    return
    origin.append(indexOrigin)
    originLabel.append(allItens[indexOrigin])
    dest.append(indexDest)
    destLabel.append(allItens[indexDest])
    value.append(1) 

    colorItem = list(np.random.choice(range(256), size=3))
    color.append(f"rgba({colorItem[0]}, {colorItem[1]}, {colorItem[2]}, 0.8)")

def GenerateInterations (allItens, origin, dest, value, color):
    qtd = 1
    for index, row in df.iterrows():
        
        catIndex = allItens.index(row['Categoria'])
     
        probList =  allItens[len(categoria):]
        probIndex =  len(categoria) + probList.index(row['Problema'])
       
        if(probIndex < catIndex):
            print(f"Inversao de valores - {row['Categoria']} - {row['Problema']}" )
            # probIndex = allItens.index(row['Problema'])

        prodList = allItens[len(categoria) + len(problema):]
        prodIndex = len(categoria) + len(problema) + prodList.index(row['Produto'])
       
        if(prodIndex < probIndex):
            print(f"Inversao de valores - {row['Problema']} - {row['Produto']}" )
        
        startList = allItens[len(produto) + len(categoria) + len(problema):]
        statIndex = len(produto) + len(categoria) + len(problema) + startList.index(row['Status'])

        if(row['Problema'] == "Qualidade da internet"):
            if(row['Categoria'] == "Não encontrei meu problema"):
                # print(qtd)
                qtd = qtd+1
        insertItem(catIndex, probIndex, origin, dest, value, color)
        insertItem(probIndex, prodIndex, origin, dest, value, color)
        insertItem(prodIndex, statIndex, origin, dest, value, color)
       
    return origin, dest, value, color



origin, dest, value, color = GenerateInterations(allItens, origin, dest, value, color)

for i in range(len(origin)):
    # print(f"{origin[i]} - {dest[i]} : {value[i]}")
    print(f"{allItens[origin[i]]} - {allItens[dest[i]]} : {value[i]}")


for i in range(len(categoria)):
    nodecolor.append("blue")   

for i in range(len(problema)):
    nodecolor.append("red")

for i in range(len(produto)):
    nodecolor.append("yellow")

for i in range(len(status)):
    nodecolor.append("green")
# Out:
# Provedores e serv. de internet - Qualidade da internet : 124
# Qualidade da internet - Internet para casa : 149
# Internet para casa - Resolvido : 1111
# Cobrança duplicada - Internet para casa : 11
# Não encontrei meu problema - Cobrança duplicada : 9
# Cobrança duplicada - Canais de Atendimento : 1
# Provedores e serv. de internet - Instabilidade de sinal : 10
# Instabilidade de sinal - Internet para computador : 10
# Instabilidade de sinal - Internet para celular : 1
# Não encontrei meu problema - Instabilidade de sinal : 1
# Provedores e serv. de internet - Qualidade do serviço prestado : 5
# Qualidade do serviço prestado - Internet para casa : 5
# Provedores e serv. de internet - Estorno do valor pago : 2
# Estorno do valor pago - Internet para casa : 4
# Não encontrei meu problema - Estorno do valor pago : 2
# Problemas com o Atendimento - Estorno do valor pago : 1
# Estorno do valor pago - Canais de Atendimento : 1
# Provedores e serv. de internet - Mau Atendimento : 5
# Mau Atendimento - Internet para casa : 5
# Problemas com o Atendimento - Mau Atendimento : 3
# Mau Atendimento - Canais de Atendimento : 3
# Telefonia fixa - Mau Atendimento : 1
# Mau Atendimento - Telefonia fixa : 1
# Provedores e serv. de internet - Login-Senha : 2
# Login-Senha - Internet para casa : 2
# Provedores e serv. de internet - Pagamento automático : 3
# Pagamento automático - Internet para casa : 5
# Não encontrei meu problema - Pagamento automático : 3
# Pagamento automático - Internet para computador : 1
# Provedores e serv. de internet - Consumo da franquia : 2
# Consumo da franquia - Internet para casa : 2
# Provedores e serv. de internet - Mau atendimento do prestador de serviço : 3
# Mau atendimento do prestador de serviço - Internet para casa : 3
# Problemas com o Atendimento - Mau atendimento do prestador de serviço : 1
# Mau atendimento do prestador de serviço - Canais de Atendimento : 1
# Telefonia fixa - Mau atendimento do prestador de serviço : 3
# Mau atendimento do prestador de serviço - Telefonia fixa : 3
# Telefonia celular - Mau atendimento do prestador de serviço : 1
# Mau atendimento do prestador de serviço - Planos pós-pagos : 1
# Provedores e serv. de internet - Serasa-SPC : 3
# Serasa-SPC - Internet para casa : 4
# Não encontrei meu problema - Serasa-SPC : 1
# Provedores e serv. de internet - Produto errado : 2
# Produto errado - Internet para casa : 2
# Provedores e serv. de internet - Não conecta à internet : 1
# Não conecta à internet - Internet para celular : 1
# Provedores e serv. de internet - Problemas com o chip : 1
# Problemas com o chip - Planos pós-pagos : 1
# Telefonia fixa - Portabilidade : 3
# Portabilidade - Telefonia fixa : 3
# Bancos - Cobrança indevida de tarifas : 1
# Cobrança indevida de tarifas - Conta : 1
# Conta - Resolvido : 1
# Cartões de Crédito - Telemarketing : 1
# Telemarketing - Cartão de crédito : 1
# Cartão de crédito - Resolvido : 1

# %%
fig = go.Figure(data=[go.Sankey(
    valueformat = "s",
    node = dict(
      pad = 20,
      thickness = 30,
      line = dict(color = "black", width = 2),
      label = allItens,
      color = nodecolor
    ),
    link = dict(
      source = origin, # indices correspond to labels, eg A1, A2, A1, B1, ...
      target = dest,
      value = value,
      color = color
  ))])

fig.update_layout(width=1500, height = 2500, font_size=13)
fig.write_html("Sankey.html")
# fig.show()
